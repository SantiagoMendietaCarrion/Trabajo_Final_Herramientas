# %%
import pandas as pd

# %%
from faker import Faker
fake = Faker()

# %%
lista = []

# %%
for x in range(0,1000):
    lista.append({'Nombre': fake.first_name(),'Apellido':fake.last_name(),'Dirección':fake.address(),'Correo electrónico':fake.email(),'Fecha de nacimiento':fake.date_of_birth()})

# %%
lista
# Out:
# [{'Nombre': 'Rachel',
#   'Apellido': 'Coleman',
#   'Dirección': '5757 Thompson Overpass\nClarkmouth, FL 20893',
#   'Correo electrónico': 'manningtina@example.com',
#   'Fecha de nacimiento': datetime.date(1931, 3, 6)},
#  {'Nombre': 'John',
#   'Apellido': 'Burns',
#   'Dirección': '404 Renee Wall Apt. 092\nNew Joshua, PA 85625',
#   'Correo electrónico': 'brownamy@example.org',
#   'Fecha de nacimiento': datetime.date(1967, 4, 24)},
#  {'Nombre': 'Douglas',
#   'Apellido': 'Ortega',
#   'Dirección': '819 Ward Plains\nEast Monica, KY 81125',
#   'Correo electrónico': 'ywilson@example.org',
#   'Fecha de nacimiento': datetime.date(1980, 6, 5)},
#  {'Nombre': 'Diana',
#   'Apellido': 'Bradley',
#   'Dirección': '0962 Amanda Crest\nSouth Abigail, VA 50910',
#   'Correo electrónico': 'hatfieldethan@example.org',
#   'Fecha de nacimiento': datetime.date(2013, 8, 10)},
#  {'Nombre': 'Chad',
#   'Apellido': 'Atkins',
#   'Dirección': '7960 Katherine Ferry Apt. 849\nLake Lisa, WY 11068',
#   'Correo electrónico': 'stephen15@example.com',
#   'Fecha de nacimiento': datetime.date(2006, 10, 8)},
#  {'Nombre': 'Danielle',
#   'Apellido': 'Wood',
#   'Dirección': '90310 Richard Row Suite 203\nEast Natasha, LA 34844',
#   'Correo electrónico': 'robinsonbrian@example.org',
#   'Fecha de nacimiento': datetime.date(1954, 6, 3)},
#  {'Nombre': 'Jerry',
#   'Apellido': 'Ross',
#   'Dirección': '201 Arnold Walks Apt. 493\nCindymouth, MI 17120',
#   'Correo electrónico': 'lbautista@example.net',
#   'Fecha de nacimiento': datetime.date(1937, 4, 29)},
#  {'Nombre': 'Luis',
#   'Apellido': 'Hernandez',
#   'Dirección': '225 Mcconnell Cliffs\nTaylorfort, AR 94836',
#   'Correo electrónico': 'woodjennifer@example.net',
#   'Fecha de nacimiento': datetime.date(1948, 7, 18)},
#  {'Nombre': 'Claudia',
#   'Apellido': 'Bishop',
#   'Dirección': '166 Phillips Fall\nNew Brandon, CO 25461',
#   'Correo electrónico': 'riddleandrew@example.net',
#   'Fecha de nacimiento': datetime.date(1917, 1, 30)},
#  {'Nombre': 'Rachel',
#   'Apellido': 'Kelly',
#   'Dirección': '519 Marshall Street Suite 159\nClarkmouth, DE 30202',
#   'Correo electrónico': 'qcross@example.org',
#   'Fecha de nacimiento': datetime.date(1923, 3, 21)},
#  {'Nombre': 'Nicholas',
#   'Apellido': 'Mitchell',
#   'Dirección': '10895 Vaughn Valley\nEast Chloe, MI 47384',
#   'Correo electrónico': 'matthewpeterson@example.org',
#   'Fecha de nacimiento': datetime.date(1962, 6, 19)},
#  {'Nombre': 'Jeff',
#   'Apellido': 'Garcia',
#   'Dirección': 'PSC 1007, Box 6277\nAPO AP 42016',
#   'Correo electrónico': 'veronica10@example.net',
#   'Fecha de nacimiento': datetime.date(1970, 1, 21)},
#  {'Nombre': 'Darlene',
#   'Apellido': 'Mitchell',
#   'Dirección': '52299 Wendy Plains Apt. 072\nWest Eddiechester, MA 85921',
#   'Correo electrónico': 'evansallison@example.com',
#   'Fecha de nacimiento': datetime.date(1956, 11, 20)},
#  {'Nombre': 'Amanda',
#   'Apellido': 'Ray',
#   'Dirección': '215 Kenneth Village Suite 986\nEast Elizabeth, NH 70697',
#   'Correo electrónico': 'lunderwood@example.org',
#   'Fecha de nacimiento': datetime.date(1947, 9, 24)},
#  {'Nombre': 'Leonard',
#   'Apellido': 'Wade',
#   'Dirección': '68151 William Square Suite 445\nPort Jacqueline, WA 77503',
#   'Correo electrónico': 'cordovajacob@example.net',
#   'Fecha de nacimiento': datetime.date(1949, 7, 25)},
#  {'Nombre': 'Leslie',
#   'Apellido': 'Perkins',
#   'Dirección': '9197 Blevins Crossing Apt. 699\nPort Paulbury, PW 08095',
#   'Correo electrónico': 'karen40@example.com',
#   'Fecha de nacimiento': datetime.date(2017, 11, 26)},
#  {'Nombre': 'Amy',
#   'Apellido': 'Manning',
#   'Dirección': '6660 Campbell Fords\nRebeccamouth, AK 65093',
#   'Correo electrónico': 'garydavenport@example.org',
#   'Fecha de nacimiento': datetime.date(2010, 4, 11)},
#  {'Nombre': 'Christine',
#   'Apellido': 'Patrick',
#   'Dirección': '49172 Price Ridges\nJamestown, AR 50395',
#   'Correo electrónico': 'danny10@example.net',
#   'Fecha de nacimiento': datetime.date(1930, 10, 14)},
#  {'Nombre': 'William',
#   'Apellido': 'Ball',
#   'Dirección': '97546 Morris Villages Apt. 130\nSouth Jamesshire, NM 97698',
#   'Correo electrónico': 'mitchelljacob@example.com',
#   'Fecha de nacimiento': datetime.date(1938, 4, 15)},
#  {'Nombre': 'Alexa',
#   'Apellido': 'Harris',
#   'Dirección': '558 Cook Skyway Apt. 779\nAllenchester, NM 05415',
#   'Correo electrónico': 'antonio87@example.org',
#   'Fecha de nacimiento': datetime.date(1923, 12, 8)},
#  {'Nombre': 'Melissa',
#   'Apellido': 'Campbell',
#   'Dirección': '10877 Obrien Rapids Suite 841\nTapiaport, VA 95105',
#   'Correo electrónico': 'smurphy@example.org',
#   'Fecha de nacimiento': datetime.date(1911, 6, 17)},
#  {'Nombre': 'Hannah',
#   'Apellido': 'Schaefer',
#   'Dirección': '605 Michael Garden\nLake Cesarshire, AZ 04091',
#   'Correo electrónico': 'latoya65@example.com',
#   'Fecha de nacimiento': datetime.date(1926, 8, 12)},
#  {'Nombre': 'Russell',
#   'Apellido': 'Lewis',
#   'Dirección': '450 Herrera Route\nOrtizport, HI 90602',
#   'Correo electrónico': 'kingabigail@example.org',
#   'Fecha de nacimiento': datetime.date(2000, 3, 7)},
#  {'Nombre': 'Renee',
#   'Apellido': 'Marquez',
#   'Dirección': '13524 Marshall Light\nPort Cameronside, NH 33405',
#   'Correo electrónico': 'jordan78@example.com',
#   'Fecha de nacimiento': datetime.date(1920, 2, 27)},
#  {'Nombre': 'Brian',
#   'Apellido': 'Sims',
#   'Dirección': '73534 Nicholson Knolls\nChristensenburgh, MI 76654',
#   'Correo electrónico': 'bwatts@example.net',
#   'Fecha de nacimiento': datetime.date(1927, 5, 9)},
#  {'Nombre': 'Kara',
#   'Apellido': 'Hall',
#   'Dirección': '579 Justin Locks Suite 438\nMichaelfort, LA 36225',
#   'Correo electrónico': 'vmarquez@example.org',
#   'Fecha de nacimiento': datetime.date(1949, 2, 14)},
#  {'Nombre': 'Aaron',
#   'Apellido': 'Rivera',
#   'Dirección': '035 Perez Lakes\nWest Nicholasfort, MT 33542',
#   'Correo electrónico': 'mcross@example.com',
#   'Fecha de nacimiento': datetime.date(1973, 9, 14)},
#  {'Nombre': 'Victoria',
#   'Apellido': 'Mcdonald',
#   'Dirección': '570 Oneal Crescent\nEast Andrew, GU 34823',
#   'Correo electrónico': 'davisjennifer@example.net',
#   'Fecha de nacimiento': datetime.date(2001, 3, 22)},
#  {'Nombre': 'Jacob',
#   'Apellido': 'Franco',
#   'Dirección': '742 Mary Street Suite 619\nNorth Katiestad, RI 73247',
#   'Correo electrónico': 'abbotttara@example.org',
#   'Fecha de nacimiento': datetime.date(1923, 10, 12)},
#  {'Nombre': 'Jeremiah',
#   'Apellido': 'Fernandez',
#   'Dirección': 'Unit 8646 Box 4571\nDPO AA 37273',
#   'Correo electrónico': 'bennettsamantha@example.org',
#   'Fecha de nacimiento': datetime.date(1941, 9, 25)},
#  {'Nombre': 'Charles',
#   'Apellido': 'West',
#   'Dirección': '94640 Mcintyre Spur Apt. 948\nNorth Ashley, GU 89705',
#   'Correo electrónico': 'john98@example.org',
#   'Fecha de nacimiento': datetime.date(1950, 3, 11)},
#  {'Nombre': 'April',
#   'Apellido': 'Floyd',
#   'Dirección': '6115 Reginald Circle Apt. 779\nJennifermouth, CA 58616',
#   'Correo electrónico': 'julie56@example.net',
#   'Fecha de nacimiento': datetime.date(1966, 9, 3)},
#  {'Nombre': 'Shawn',
#   'Apellido': 'Miles',
#   'Dirección': '75084 Lisa Villages Apt. 900\nAndrewview, NE 65162',
#   'Correo electrónico': 'joshuascott@example.com',
#   'Fecha de nacimiento': datetime.date(1937, 10, 8)},
#  {'Nombre': 'Kevin',
#   'Apellido': 'Cardenas',
#   'Dirección': '3313 Rush Extensions Apt. 137\nPort Lucaschester, KS 66967',
#   'Correo electrónico': 'karen24@example.org',
#   'Fecha de nacimiento': datetime.date(1985, 4, 15)},
#  {'Nombre': 'Beth',
#   'Apellido': 'Harris',
#   'Dirección': '00791 Joseph Crossroad\nNew Danielstad, VA 19935',
#   'Correo electrónico': 'richard78@example.org',
#   'Fecha de nacimiento': datetime.date(2014, 12, 5)},
#  {'Nombre': 'Micheal',
#   'Apellido': 'Wright',
#   'Dirección': '590 Jason Village\nLopezton, OH 62000',
#   'Correo electrónico': 'hgomez@example.com',
#   'Fecha de nacimiento': datetime.date(1909, 2, 6)},
#  {'Nombre': 'Rebecca',
#   'Apellido': 'Barber',
#   'Dirección': '702 Stephen Estate Apt. 395\nNew Sara, TN 94244',
#   'Correo electrónico': 'fchen@example.com',
#   'Fecha de nacimiento': datetime.date(1955, 6, 18)},
#  {'Nombre': 'Joseph',
#   'Apellido': 'Aguirre',
#   'Dirección': '196 Harper View Suite 293\nLake Martin, CO 19935',
#   'Correo electrónico': 'yorkrobin@example.com',
#   'Fecha de nacimiento': datetime.date(1958, 4, 13)},
#  {'Nombre': 'Shirley',
#   'Apellido': 'Fitzgerald',
#   'Dirección': '504 Michelle Vista Apt. 373\nSchwartzburgh, IA 84884',
#   'Correo electrónico': 'danielcollins@example.com',
#   'Fecha de nacimiento': datetime.date(2011, 1, 10)},
#  {'Nombre': 'Crystal',
#   'Apellido': 'Davis',
#   'Dirección': '5030 Huff Turnpike Suite 305\nNorth Vincentburgh, MA 59119',
#   'Correo electrónico': 'tpeters@example.com',
#   'Fecha de nacimiento': datetime.date(2012, 11, 26)},
#  {'Nombre': 'Mark',
#   'Apellido': 'Bray',
#   'Dirección': '97791 Bobby Fort Suite 985\nSouth Christopher, MP 62518',
#   'Correo electrónico': 'yturner@example.org',
#   'Fecha de nacimiento': datetime.date(2021, 5, 19)},
#  {'Nombre': 'Tricia',
#   'Apellido': 'Davis',
#   'Dirección': '68051 Harmon Extension Suite 185\nNorth Ryanburgh, OH 77326',
#   'Correo electrónico': 'hernandezlisa@example.net',
#   'Fecha de nacimiento': datetime.date(1931, 6, 28)},
#  {'Nombre': 'Tyler',
#   'Apellido': 'Price',
#   'Dirección': '36252 Martha Ville Suite 292\nMayland, MD 55921',
#   'Correo electrónico': 'sknight@example.net',
#   'Fecha de nacimiento': datetime.date(1909, 10, 6)},
#  {'Nombre': 'Paul',
#   'Apellido': 'Knight',
#   'Dirección': '0186 Mathis Corner\nWest Georgeborough, ME 33232',
#   'Correo electrónico': 'jessica32@example.org',
#   'Fecha de nacimiento': datetime.date(2005, 7, 19)},
#  {'Nombre': 'Kristin',
#   'Apellido': 'Taylor',
#   'Dirección': '33576 Sean Drive\nLake Laura, NC 53995',
#   'Correo electrónico': 'gsantos@example.net',
#   'Fecha de nacimiento': datetime.date(1997, 11, 28)},
#  {'Nombre': 'Timothy',
#   'Apellido': 'Moore',
#   'Dirección': '5881 Blake View\nRachaelton, IL 06002',
#   'Correo electrónico': 'marystevenson@example.com',
#   'Fecha de nacimiento': datetime.date(1932, 11, 17)},
#  {'Nombre': 'Maria',
#   'Apellido': 'Stanley',
#   'Dirección': '451 Alexis Dale\nTiffanymouth, UT 15957',
#   'Correo electrónico': 'dmills@example.com',
#   'Fecha de nacimiento': datetime.date(1916, 2, 25)},
#  {'Nombre': 'Mark',
#   'Apellido': 'Thomas',
#   'Dirección': '41623 Miles Brook Apt. 502\nSouth Patrick, PA 51096',
#   'Correo electrónico': 'tdougherty@example.net',
#   'Fecha de nacimiento': datetime.date(2005, 11, 15)},
#  {'Nombre': 'Maria',
#   'Apellido': 'Zamora',
#   'Dirección': '1454 Margaret Port Apt. 680\nCampostown, PA 53564',
#   'Correo electrónico': 'nicholas45@example.com',
#   'Fecha de nacimiento': datetime.date(1943, 12, 20)},
#  {'Nombre': 'Brianna',
#   'Apellido': 'Richmond',
#   'Dirección': '70010 Lopez Plaza\nRobinsonburgh, RI 84340',
#   'Correo electrónico': 'anthonyjones@example.net',
#   'Fecha de nacimiento': datetime.date(1961, 8, 12)},
#  {'Nombre': 'Kenneth',
#   'Apellido': 'Hughes',
#   'Dirección': '505 Mary Trail\nTonyachester, AZ 10009',
#   'Correo electrónico': 'brosales@example.org',
#   'Fecha de nacimiento': datetime.date(1947, 3, 10)},
#  {'Nombre': 'David',
#   'Apellido': 'Trujillo',
#   'Dirección': '71072 Washington Key Suite 168\nEast Jodyshire, OR 71589',
#   'Correo electrónico': 'olawrence@example.net',
#   'Fecha de nacimiento': datetime.date(1911, 8, 16)},
#  {'Nombre': 'William',
#   'Apellido': 'Dennis',
#   'Dirección': '6574 Chase Manor\nPort James, CT 03982',
#   'Correo electrónico': 'angela15@example.com',
#   'Fecha de nacimiento': datetime.date(1933, 12, 11)},
#  {'Nombre': 'Brian',
#   'Apellido': 'Holt',
#   'Dirección': '10730 Bonilla Skyway\nSouth Scotttown, NY 37542',
#   'Correo electrónico': 'donaldclark@example.org',
#   'Fecha de nacimiento': datetime.date(1968, 4, 16)},
#  {'Nombre': 'Jillian',
#   'Apellido': 'Gray',
#   'Dirección': '73733 Christopher Walk Apt. 283\nCombsshire, WY 56867',
#   'Correo electrónico': 'ronaldriley@example.com',
#   'Fecha de nacimiento': datetime.date(1930, 10, 18)},
#  {'Nombre': 'Brittany',
#   'Apellido': 'Palmer',
#   'Dirección': '4682 Kyle Ways\nKyleview, MT 08697',
#   'Correo electrónico': 'bcooper@example.net',
#   'Fecha de nacimiento': datetime.date(1957, 6, 6)},
#  {'Nombre': 'Derek',
#   'Apellido': 'Johnson',
#   'Dirección': '61479 Powell Unions\nNorth Lynnstad, IN 33650',
#   'Correo electrónico': 'ifowler@example.com',
#   'Fecha de nacimiento': datetime.date(2018, 8, 3)},
#  {'Nombre': 'Jeffrey',
#   'Apellido': 'Glenn',
#   'Dirección': '013 Steven Shoal\nAndersonville, VI 47423',
#   'Correo electrónico': 'ebrown@example.org',
#   'Fecha de nacimiento': datetime.date(2007, 10, 18)},
#  {'Nombre': 'Kevin',
#   'Apellido': 'Duran',
#   'Dirección': '5596 John Crescent\nWilliamfurt, NH 98540',
#   'Correo electrónico': 'portermax@example.net',
#   'Fecha de nacimiento': datetime.date(1921, 3, 29)},
#  {'Nombre': 'Shannon',
#   'Apellido': 'Wong',
#   'Dirección': '6346 Cheryl Viaduct\nJohnberg, CA 97449',
#   'Correo electrónico': 'fcarlson@example.org',
#   'Fecha de nacimiento': datetime.date(1999, 9, 8)},
#  {'Nombre': 'Shannon',
#   'Apellido': 'Boyd',
#   'Dirección': '516 Jennifer Walk Apt. 789\nDeborahmouth, MS 94346',
#   'Correo electrónico': 'xphillips@example.net',
#   'Fecha de nacimiento': datetime.date(1996, 2, 8)},
#  {'Nombre': 'Jessica',
#   'Apellido': 'Hernandez',
#   'Dirección': '1640 Bennett Meadow\nBrittanyhaven, NH 49958',
#   'Correo electrónico': 'shaunmoore@example.com',
#   'Fecha de nacimiento': datetime.date(2017, 9, 18)},
#  {'Nombre': 'Anthony',
#   'Apellido': 'Young',
#   'Dirección': '4291 Harris Causeway\nCarsonland, KY 57982',
#   'Correo electrónico': 'anthonyfrank@example.com',
#   'Fecha de nacimiento': datetime.date(1999, 2, 3)},
#  {'Nombre': 'Christine',
#   'Apellido': 'Velasquez',
#   'Dirección': '203 Kimberly Springs\nNew Tamaraburgh, FM 18680',
#   'Correo electrónico': 'sarahcollins@example.com',
#   'Fecha de nacimiento': datetime.date(1986, 1, 8)},
#  {'Nombre': 'Felicia',
#   'Apellido': 'Anderson',
#   'Dirección': 'USNS Howard\nFPO AE 29135',
#   'Correo electrónico': 'veronica80@example.net',
#   'Fecha de nacimiento': datetime.date(1911, 10, 2)},
#  {'Nombre': 'Kathy',
#   'Apellido': 'Nolan',
#   'Dirección': '96469 Nunez Turnpike Apt. 796\nNorth Joseph, WV 38410',
#   'Correo electrónico': 'bdudley@example.net',
#   'Fecha de nacimiento': datetime.date(1908, 11, 9)},
#  {'Nombre': 'Brian',
#   'Apellido': 'Mendoza',
#   'Dirección': '85822 Troy Islands\nYounghaven, VT 58537',
#   'Correo electrónico': 'john89@example.com',
#   'Fecha de nacimiento': datetime.date(2014, 4, 9)},
#  {'Nombre': 'Luis',
#   'Apellido': 'Flynn',
#   'Dirección': '9297 Ray Glen\nPort Bruce, MA 91865',
#   'Correo electrónico': 'moorediana@example.org',
#   'Fecha de nacimiento': datetime.date(1916, 2, 21)},
#  {'Nombre': 'Jason',
#   'Apellido': 'Dennis',
#   'Dirección': '1754 Jamie Circles\nPort Michelleland, WI 70652',
#   'Correo electrónico': 'michaeljones@example.net',
#   'Fecha de nacimiento': datetime.date(2001, 11, 25)},
#  {'Nombre': 'Jennifer',
#   'Apellido': 'Jimenez',
#   'Dirección': '093 Villegas Union Suite 885\nMcgeebury, NJ 34736',
#   'Correo electrónico': 'josephcordova@example.org',
#   'Fecha de nacimiento': datetime.date(1921, 3, 1)},
#  {'Nombre': 'Caitlin',
#   'Apellido': 'Mcdaniel',
#   'Dirección': '247 Terry Mall\nEast Randyburgh, AR 74892',
#   'Correo electrónico': 'gravesdavid@example.net',
#   'Fecha de nacimiento': datetime.date(1986, 9, 19)},
#  {'Nombre': 'Tammie',
#   'Apellido': 'Scott',
#   'Dirección': '06524 Logan Burg Apt. 029\nPort Andrew, IL 49765',
#   'Correo electrónico': 'christophergomez@example.com',
#   'Fecha de nacimiento': datetime.date(1987, 8, 12)},
#  {'Nombre': 'Caroline',
#   'Apellido': 'Alvarado',
#   'Dirección': '09756 James Grove Suite 516\nLake Christopherton, VA 97436',
#   'Correo electrónico': 'jerry20@example.org',
#   'Fecha de nacimiento': datetime.date(2009, 11, 17)},
#  {'Nombre': 'David',
#   'Apellido': 'Rogers',
#   'Dirección': '49474 Daniel Island\nArnoldland, MO 69158',
#   'Correo electrónico': 'jessicashort@example.com',
#   'Fecha de nacimiento': datetime.date(1948, 4, 26)},
#  {'Nombre': 'Donna',
#   'Apellido': 'White',
#   'Dirección': '1640 Rebecca Plain Apt. 085\nWest Jasonburgh, OH 11736',
#   'Correo electrónico': 'rrodriguez@example.com',
#   'Fecha de nacimiento': datetime.date(1996, 1, 24)},
#  {'Nombre': 'Lindsay',
#   'Apellido': 'Solis',
#   'Dirección': '79589 Benton Mill Suite 441\nDonovanfurt, CO 76958',
#   'Correo electrónico': 'wellssarah@example.org',
#   'Fecha de nacimiento': datetime.date(1915, 8, 25)},
#  {'Nombre': 'Bailey',
#   'Apellido': 'Baker',
#   'Dirección': '31319 Benton Stravenue Suite 010\nBarbaramouth, AK 79539',
#   'Correo electrónico': 'iwilson@example.org',
#   'Fecha de nacimiento': datetime.date(1980, 7, 13)},
#  {'Nombre': 'Lori',
#   'Apellido': 'Johnson',
#   'Dirección': 'PSC 6282, Box 8776\nAPO AE 07377',
#   'Correo electrónico': 'natalie90@example.org',
#   'Fecha de nacimiento': datetime.date(1949, 3, 26)},
#  {'Nombre': 'Michelle',
#   'Apellido': 'Munoz',
#   'Dirección': '9664 Patrick Tunnel\nEmilybury, DC 71528',
#   'Correo electrónico': 'chamberskristina@example.net',
#   'Fecha de nacimiento': datetime.date(1987, 1, 17)},
#  {'Nombre': 'Francisco',
#   'Apellido': 'Thompson',
#   'Dirección': '470 Jasmine Stravenue\nSouth Kristina, NY 66964',
#   'Correo electrónico': 'alexismitchell@example.net',
#   'Fecha de nacimiento': datetime.date(2022, 10, 29)},
#  {'Nombre': 'Bradley',
#   'Apellido': 'Kaufman',
#   'Dirección': '09911 Buchanan Plaza Suite 322\nCathyfurt, UT 63213',
#   'Correo electrónico': 'johnsonronnie@example.com',
#   'Fecha de nacimiento': datetime.date(1926, 11, 23)},
#  {'Nombre': 'Pamela',
#   'Apellido': 'King',
#   'Dirección': '037 Glenn Garden\nWrightbury, WY 25656',
#   'Correo electrónico': 'michellebowen@example.net',
#   'Fecha de nacimiento': datetime.date(1987, 1, 11)},
#  {'Nombre': 'Evelyn',
#   'Apellido': 'Steele',
#   'Dirección': '54568 Ramirez Ports Suite 654\nMelodyville, CA 14643',
#   'Correo electrónico': 'manuel57@example.org',
#   'Fecha de nacimiento': datetime.date(1949, 8, 9)},
#  {'Nombre': 'Jennifer',
#   'Apellido': 'White',
#   'Dirección': '679 David Mountain Suite 524\nBrandonberg, MI 37534',
#   'Correo electrónico': 'tpark@example.com',
#   'Fecha de nacimiento': datetime.date(1986, 8, 9)},
#  {'Nombre': 'Amanda',
#   'Apellido': 'Johns',
#   'Dirección': '535 Long Flats\nNorth Emilytown, KY 59768',
#   'Correo electrónico': 'millerjeffery@example.net',
#   'Fecha de nacimiento': datetime.date(1960, 10, 26)},
#  {'Nombre': 'Thomas',
#   'Apellido': 'Giles',
#   'Dirección': '49889 Bailey Heights\nPort Tonya, WV 81034',
#   'Correo electrónico': 'mbuck@example.net',
#   'Fecha de nacimiento': datetime.date(1967, 9, 12)},
#  {'Nombre': 'Dave',
#   'Apellido': 'Avila',
#   'Dirección': '1120 Bryan Crossroad\nAbbottmouth, RI 88311',
#   'Correo electrónico': 'allenandrew@example.net',
#   'Fecha de nacimiento': datetime.date(1949, 7, 17)},
#  {'Nombre': 'Lori',
#   'Apellido': 'Hunter',
#   'Dirección': 'PSC 8730, Box 7421\nAPO AA 26809',
#   'Correo electrónico': 'scottwest@example.net',
#   'Fecha de nacimiento': datetime.date(1988, 9, 28)},
#  {'Nombre': 'Jennifer',
#   'Apellido': 'Hawkins',
#   'Dirección': '96348 Jennifer Flats\nEast Patrick, HI 56473',
#   'Correo electrónico': 'xjones@example.com',
#   'Fecha de nacimiento': datetime.date(1995, 8, 23)},
#  {'Nombre': 'Kimberly',
#   'Apellido': 'Compton',
#   'Dirección': '95661 Brown Prairie\nBarbaratown, NM 43679',
#   'Correo electrónico': 'amber14@example.com',
#   'Fecha de nacimiento': datetime.date(1921, 6, 26)},
#  {'Nombre': 'Shawn',
#   'Apellido': 'Johnson',
#   'Dirección': '31643 Hannah Trail\nNorth Kylemouth, AL 05612',
#   'Correo electrónico': 'natalie44@example.com',
#   'Fecha de nacimiento': datetime.date(1994, 9, 5)},
#  {'Nombre': 'Margaret',
#   'Apellido': 'Brown',
#   'Dirección': '194 Stephens Glens\nCristinaburgh, LA 49376',
#   'Correo electrónico': 'adamjackson@example.org',
#   'Fecha de nacimiento': datetime.date(1920, 1, 27)},
#  {'Nombre': 'Danny',
#   'Apellido': 'Schultz',
#   'Dirección': '715 Wilkinson Track\nPort Angelicamouth, NE 69195',
#   'Correo electrónico': 'perezchad@example.org',
#   'Fecha de nacimiento': datetime.date(1930, 4, 15)},
#  {'Nombre': 'Melissa',
#   'Apellido': 'Kelley',
#   'Dirección': '41011 Eric Island Suite 990\nLake Danielleside, KS 62702',
#   'Correo electrónico': 'mendozarobin@example.net',
#   'Fecha de nacimiento': datetime.date(1927, 2, 24)},
#  {'Nombre': 'Joseph',
#   'Apellido': 'Ryan',
#   'Dirección': '3509 Justin Ford Apt. 652\nNorth Amyshire, NM 83825',
#   'Correo electrónico': 'nicholasblack@example.org',
#   'Fecha de nacimiento': datetime.date(1984, 10, 30)},
#  {'Nombre': 'Tara',
#   'Apellido': 'Miller',
#   'Dirección': '9233 Robert Gateway Apt. 119\nWellston, NY 39938',
#   'Correo electrónico': 'robinrichardson@example.org',
#   'Fecha de nacimiento': datetime.date(1969, 3, 19)},
#  {'Nombre': 'Victoria',
#   'Apellido': 'Jenkins',
#   'Dirección': '8684 Proctor Underpass\nNew Eric, TN 05152',
#   'Correo electrónico': 'williamfox@example.org',
#   'Fecha de nacimiento': datetime.date(2011, 9, 18)},
#  {'Nombre': 'Elizabeth',
#   'Apellido': 'Johnson',
#   'Dirección': '711 Garcia Loop\nEdwardchester, OH 66402',
#   'Correo electrónico': 'tmueller@example.com',
#   'Fecha de nacimiento': datetime.date(2011, 8, 23)},
#  {'Nombre': 'Randall',
#   'Apellido': 'Hopkins',
#   'Dirección': '78442 Christina Shoal Suite 615\nWest Daniel, TX 02799',
#   'Correo electrónico': 'mariablanchard@example.org',
#   'Fecha de nacimiento': datetime.date(1929, 12, 8)},
#  {'Nombre': 'Tommy',
#   'Apellido': 'Carter',
#   'Dirección': '5550 Mary Trace Apt. 112\nWest Laura, CA 34830',
#   'Correo electrónico': 'deborahjoyce@example.com',
#   'Fecha de nacimiento': datetime.date(1937, 1, 5)},
#  {'Nombre': 'Sarah',
#   'Apellido': 'Elliott',
#   'Dirección': '22222 Erickson Station Suite 660\nWest Whitney, VT 17350',
#   'Correo electrónico': 'michael66@example.net',
#   'Fecha de nacimiento': datetime.date(1912, 12, 1)},
#  {'Nombre': 'Ashley',
#   'Apellido': 'Sanford',
#   'Dirección': 'Unit 8211 Box 4729\nDPO AE 42214',
#   'Correo electrónico': 'rodriguezamy@example.com',
#   'Fecha de nacimiento': datetime.date(2007, 4, 14)},
#  {'Nombre': 'Krista',
#   'Apellido': 'Griffin',
#   'Dirección': '3410 Melissa Port\nSouth Matthew, ND 21797',
#   'Correo electrónico': 'mmitchell@example.net',
#   'Fecha de nacimiento': datetime.date(1940, 8, 6)},
#  {'Nombre': 'Joel',
#   'Apellido': 'Hoffman',
#   'Dirección': '1773 Eric Islands\nBrianland, GA 76709',
#   'Correo electrónico': 'leemichelle@example.org',
#   'Fecha de nacimiento': datetime.date(1920, 9, 1)},
#  {'Nombre': 'David',
#   'Apellido': 'Alvarez',
#   'Dirección': 'Unit 1387 Box 7123\nDPO AA 57517',
#   'Correo electrónico': 'krice@example.org',
#   'Fecha de nacimiento': datetime.date(1993, 9, 28)},
#  {'Nombre': 'Tracy',
#   'Apellido': 'Taylor',
#   'Dirección': '052 Lori Manor Suite 640\nSouth Matthewmouth, VT 14655',
#   'Correo electrónico': 'janenichols@example.net',
#   'Fecha de nacimiento': datetime.date(1979, 10, 27)},
#  {'Nombre': 'Richard',
#   'Apellido': 'Stewart',
#   'Dirección': 'USCGC Jimenez\nFPO AE 58872',
#   'Correo electrónico': 'johnsonsarah@example.org',
#   'Fecha de nacimiento': datetime.date(1985, 10, 28)},
#  {'Nombre': 'Heidi',
#   'Apellido': 'Bennett',
#   'Dirección': '67249 Jessica Extensions Apt. 077\nNorth Louisfurt, LA 55523',
#   'Correo electrónico': 'craig58@example.org',
#   'Fecha de nacimiento': datetime.date(1939, 11, 26)},
#  {'Nombre': 'Amanda',
#   'Apellido': 'Fry',
#   'Dirección': '0388 Dickerson Parkway Apt. 535\nGaryburgh, FM 70491',
#   'Correo electrónico': 'grayhayley@example.net',
#   'Fecha de nacimiento': datetime.date(1946, 5, 22)},
#  {'Nombre': 'Margaret',
#   'Apellido': 'Salazar',
#   'Dirección': '2810 Morris Viaduct\nNorth Kenneth, MD 34178',
#   'Correo electrónico': 'darlenebowen@example.com',
#   'Fecha de nacimiento': datetime.date(1976, 11, 29)},
#  {'Nombre': 'Albert',
#   'Apellido': 'Webster',
#   'Dirección': 'Unit 5507 Box 9840\nDPO AA 97102',
#   'Correo electrónico': 'cwilliams@example.org',
#   'Fecha de nacimiento': datetime.date(1998, 7, 29)},
#  {'Nombre': 'Caitlin',
#   'Apellido': 'Johnson',
#   'Dirección': '22889 Veronica Terrace\nButlerberg, FL 96197',
#   'Correo electrónico': 'jennifermitchell@example.net',
#   'Fecha de nacimiento': datetime.date(1921, 2, 10)},
#  {'Nombre': 'Henry',
#   'Apellido': 'Franco',
#   'Dirección': '6452 Joe Square\nMccannchester, NJ 50565',
#   'Correo electrónico': 'hillkaren@example.org',
#   'Fecha de nacimiento': datetime.date(1976, 3, 28)},
#  {'Nombre': 'Brian',
#   'Apellido': 'Turner',
#   'Dirección': '236 Vincent Plains Apt. 387\nVeronicaside, WV 38458',
#   'Correo electrónico': 'jason19@example.com',
#   'Fecha de nacimiento': datetime.date(1911, 1, 1)},
#  {'Nombre': 'Connie',
#   'Apellido': 'Thomas',
#   'Dirección': '115 Harrington Junctions Suite 003\nWest Kimberly, AL 50826',
#   'Correo electrónico': 'angelarobinson@example.net',
#   'Fecha de nacimiento': datetime.date(1998, 2, 3)},
#  {'Nombre': 'Christian',
#   'Apellido': 'Lopez',
#   'Dirección': '74402 Shannon Fort\nNew Michellechester, NV 90904',
#   'Correo electrónico': 'jenniferwalker@example.org',
#   'Fecha de nacimiento': datetime.date(1953, 7, 7)},
#  {'Nombre': 'Gloria',
#   'Apellido': 'Bradford',
#   'Dirección': '5992 Jeremiah Groves\nJosechester, UT 04812',
#   'Correo electrónico': 'morrisonjennifer@example.com',
#   'Fecha de nacimiento': datetime.date(1968, 1, 24)},
#  {'Nombre': 'Cory',
#   'Apellido': 'Wilkerson',
#   'Dirección': '5963 Anderson Brooks Apt. 101\nBrownport, GA 43111',
#   'Correo electrónico': 'charles33@example.net',
#   'Fecha de nacimiento': datetime.date(1990, 9, 3)},
#  {'Nombre': 'Zachary',
#   'Apellido': 'Preston',
#   'Dirección': '490 Brandon Port Apt. 207\nSarahshire, AL 54786',
#   'Correo electrónico': 'allen89@example.net',
#   'Fecha de nacimiento': datetime.date(1911, 9, 4)},
#  {'Nombre': 'Cory',
#   'Apellido': 'Carr',
#   'Dirección': '4121 Alice Flats Suite 414\nSkinnerside, VI 41829',
#   'Correo electrónico': 'vargasmichael@example.org',
#   'Fecha de nacimiento': datetime.date(2019, 2, 21)},
#  {'Nombre': 'Bridget',
#   'Apellido': 'Brown',
#   'Dirección': '688 Patterson Shoals\nEast Susanland, IL 49290',
#   'Correo electrónico': 'brewertroy@example.org',
#   'Fecha de nacimiento': datetime.date(1944, 11, 9)},
#  {'Nombre': 'Wayne',
#   'Apellido': 'Mcpherson',
#   'Dirección': '16452 Wheeler Expressway\nEast Cherylside, CA 65648',
#   'Correo electrónico': 'silvakevin@example.com',
#   'Fecha de nacimiento': datetime.date(2011, 2, 18)},
#  {'Nombre': 'Jacob',
#   'Apellido': 'Moore',
#   'Dirección': '25731 Bonnie Motorway Apt. 230\nNew Erinfort, AK 91101',
#   'Correo electrónico': 'mark54@example.net',
#   'Fecha de nacimiento': datetime.date(1948, 12, 5)},
#  {'Nombre': 'Jennifer',
#   'Apellido': 'Diaz',
#   'Dirección': '046 Jason Street\nEast Jorge, VA 81295',
#   'Correo electrónico': 'coletina@example.com',
#   'Fecha de nacimiento': datetime.date(1953, 2, 11)},
#  {'Nombre': 'Joseph',
#   'Apellido': 'Snyder',
#   'Dirección': '67186 Aaron Plain\nNguyenhaven, IA 39737',
#   'Correo electrónico': 'armstrongdaniel@example.net',
#   'Fecha de nacimiento': datetime.date(1935, 3, 2)},
#  {'Nombre': 'Ashley',
#   'Apellido': 'Castillo',
#   'Dirección': '446 Jake Turnpike Apt. 442\nZacharyfurt, DC 24283',
#   'Correo electrónico': 'michellejohnson@example.net',
#   'Fecha de nacimiento': datetime.date(2018, 8, 22)},
#  {'Nombre': 'Amanda',
#   'Apellido': 'Garza',
#   'Dirección': '90528 Stephanie Ramp\nLauraburgh, MH 23153',
#   'Correo electrónico': 'larapatrick@example.net',
#   'Fecha de nacimiento': datetime.date(1916, 8, 24)},
#  {'Nombre': 'Ann',
#   'Apellido': 'Sims',
#   'Dirección': '635 Allison Locks Apt. 468\nRyanland, AK 79563',
#   'Correo electrónico': 'qbarnett@example.org',
#   'Fecha de nacimiento': datetime.date(1911, 7, 3)},
#  {'Nombre': 'Michelle',
#   'Apellido': 'Welch',
#   'Dirección': '7259 Mcguire Extension Suite 214\nNorth Bryan, AK 35000',
#   'Correo electrónico': 'jbaker@example.org',
#   'Fecha de nacimiento': datetime.date(1978, 3, 5)},
#  {'Nombre': 'William',
#   'Apellido': 'Hart',
#   'Dirección': 'USCGC Peterson\nFPO AE 41021',
#   'Correo electrónico': 'jorge10@example.org',
#   'Fecha de nacimiento': datetime.date(2010, 10, 7)},
#  {'Nombre': 'Jeffrey',
#   'Apellido': 'Edwards',
#   'Dirección': 'Unit 1798 Box 9954\nDPO AA 05948',
#   'Correo electrónico': 'curtisoconnor@example.org',
#   'Fecha de nacimiento': datetime.date(2007, 2, 8)},
#  {'Nombre': 'Caleb',
#   'Apellido': 'French',
#   'Dirección': '9918 Derek Coves Suite 118\nWellschester, TX 69059',
#   'Correo electrónico': 'smithstephen@example.org',
#   'Fecha de nacimiento': datetime.date(1910, 10, 7)},
#  {'Nombre': 'Angie',
#   'Apellido': 'Hunt',
#   'Dirección': '673 Taylor Walks Suite 166\nEast Thomastown, HI 24643',
#   'Correo electrónico': 'sheltonmichelle@example.com',
#   'Fecha de nacimiento': datetime.date(1967, 3, 20)},
#  {'Nombre': 'Brian',
#   'Apellido': 'Snow',
#   'Dirección': '689 Hooper Field\nRogersborough, FM 75351',
#   'Correo electrónico': 'jonathan99@example.com',
#   'Fecha de nacimiento': datetime.date(1957, 10, 25)},
#  {'Nombre': 'Krystal',
#   'Apellido': 'Trujillo',
#   'Dirección': '628 Sergio Turnpike Suite 968\nPeggyburgh, IL 08430',
#   'Correo electrónico': 'yhartman@example.com',
#   'Fecha de nacimiento': datetime.date(1981, 6, 5)},
#  {'Nombre': 'Joel',
#   'Apellido': 'Odom',
#   'Dirección': '863 Frazier Cliffs\nWest Nicholasshire, FM 23099',
#   'Correo electrónico': 'courtney20@example.net',
#   'Fecha de nacimiento': datetime.date(1938, 3, 29)},
#  {'Nombre': 'Matthew',
#   'Apellido': 'Pacheco',
#   'Dirección': '5658 Angela Corners Suite 311\nLake Donside, VT 86788',
#   'Correo electrónico': 'edavis@example.net',
#   'Fecha de nacimiento': datetime.date(1913, 12, 22)},
#  {'Nombre': 'Paul',
#   'Apellido': 'Boyd',
#   'Dirección': '5341 Ellison Lake\nWest Christopherfurt, FL 16227',
#   'Correo electrónico': 'chad17@example.net',
#   'Fecha de nacimiento': datetime.date(1913, 7, 20)},
#  {'Nombre': 'Michael',
#   'Apellido': 'Wallace',
#   'Dirección': 'USS Morales\nFPO AE 30042',
#   'Correo electrónico': 'ladams@example.org',
#   'Fecha de nacimiento': datetime.date(1964, 8, 14)},
#  {'Nombre': 'Shane',
#   'Apellido': 'Cantrell',
#   'Dirección': '3492 Richard Lakes\nNew Timothymouth, MS 98772',
#   'Correo electrónico': 'samuel48@example.com',
#   'Fecha de nacimiento': datetime.date(1996, 9, 8)},
#  {'Nombre': 'Kristy',
#   'Apellido': 'Hernandez',
#   'Dirección': '33232 Hodge Manor Apt. 960\nThomasland, VI 60819',
#   'Correo electrónico': 'tiffanywright@example.net',
#   'Fecha de nacimiento': datetime.date(2011, 6, 15)},
#  {'Nombre': 'Kevin',
#   'Apellido': 'King',
#   'Dirección': '410 Randall Street Suite 670\nMerrittberg, KY 72168',
#   'Correo electrónico': 'alexandra86@example.com',
#   'Fecha de nacimiento': datetime.date(1998, 4, 12)},
#  {'Nombre': 'Ryan',
#   'Apellido': 'Schroeder',
#   'Dirección': '5750 Meyer Grove\nWest Mark, MD 13583',
#   'Correo electrónico': 'vwatson@example.net',
#   'Fecha de nacimiento': datetime.date(1948, 6, 16)},
#  {'Nombre': 'Christina',
#   'Apellido': 'Flores',
#   'Dirección': '378 Miller Cliffs Apt. 041\nNew Tiffanyfort, NV 96757',
#   'Correo electrónico': 'austinknox@example.net',
#   'Fecha de nacimiento': datetime.date(2010, 1, 26)},
#  {'Nombre': 'Alexander',
#   'Apellido': 'Sanchez',
#   'Dirección': '911 Joan Haven\nBriggschester, MP 29084',
#   'Correo electrónico': 'pwood@example.net',
#   'Fecha de nacimiento': datetime.date(1985, 6, 11)},
#  {'Nombre': 'Anthony',
#   'Apellido': 'Walters',
#   'Dirección': 'Unit 8565 Box 6974\nDPO AA 09363',
#   'Correo electrónico': 'brianandrews@example.com',
#   'Fecha de nacimiento': datetime.date(1991, 8, 13)},
#  {'Nombre': 'Tyler',
#   'Apellido': 'Allen',
#   'Dirección': '16590 Russell Cape Apt. 595\nFischermouth, NJ 49089',
#   'Correo electrónico': 'lpope@example.net',
#   'Fecha de nacimiento': datetime.date(1988, 2, 17)},
#  {'Nombre': 'Daniel',
#   'Apellido': 'Clay',
#   'Dirección': '34968 Bowen Forge Suite 153\nBarronstad, AZ 45949',
#   'Correo electrónico': 'tjohnson@example.com',
#   'Fecha de nacimiento': datetime.date(1909, 7, 23)},
#  {'Nombre': 'Kimberly',
#   'Apellido': 'Velez',
#   'Dirección': '285 Christian Cliffs Apt. 976\nEast Amanda, ID 26595',
#   'Correo electrónico': 'salexander@example.net',
#   'Fecha de nacimiento': datetime.date(1983, 10, 25)},
#  {'Nombre': 'Audrey',
#   'Apellido': 'Evans',
#   'Dirección': 'USS Ray\nFPO AE 26508',
#   'Correo electrónico': 'msmith@example.org',
#   'Fecha de nacimiento': datetime.date(1964, 8, 1)},
#  {'Nombre': 'Erica',
#   'Apellido': 'Cook',
#   'Dirección': '60751 Nicole Neck\nSilvamouth, ID 81799',
#   'Correo electrónico': 'urobinson@example.com',
#   'Fecha de nacimiento': datetime.date(1969, 2, 28)},
#  {'Nombre': 'Lindsey',
#   'Apellido': 'Meyer',
#   'Dirección': '8012 Jonathan Falls Apt. 103\nDaleland, WV 04185',
#   'Correo electrónico': 'jenniferkennedy@example.com',
#   'Fecha de nacimiento': datetime.date(1973, 3, 23)},
#  {'Nombre': 'Tracey',
#   'Apellido': 'Hardin',
#   'Dirección': '437 Jones Crescent\nLake Karinatown, AL 53889',
#   'Correo electrónico': 'hernandezlee@example.org',
#   'Fecha de nacimiento': datetime.date(1929, 12, 24)},
#  {'Nombre': 'Alyssa',
#   'Apellido': 'Thomas',
#   'Dirección': '582 James Tunnel Suite 747\nMckenzietown, IL 88578',
#   'Correo electrónico': 'richardsonpaul@example.org',
#   'Fecha de nacimiento': datetime.date(1934, 10, 8)},
#  {'Nombre': 'Darryl',
#   'Apellido': 'Vargas',
#   'Dirección': '06158 Jessica Crossing Apt. 955\nRubiostad, AK 28615',
#   'Correo electrónico': 'jasonyoung@example.net',
#   'Fecha de nacimiento': datetime.date(1990, 3, 7)},
#  {'Nombre': 'Amanda',
#   'Apellido': 'Ortiz',
#   'Dirección': '4310 Scott Orchard\nEmilyland, NV 99440',
#   'Correo electrónico': 'bryan94@example.net',
#   'Fecha de nacimiento': datetime.date(1952, 3, 31)},
#  {'Nombre': 'Isaac',
#   'Apellido': 'Roach',
#   'Dirección': 'Unit 0086 Box 8097\nDPO AA 35730',
#   'Correo electrónico': 'wendy27@example.com',
#   'Fecha de nacimiento': datetime.date(1950, 5, 6)},
#  {'Nombre': 'Jodi',
#   'Apellido': 'Salazar',
#   'Dirección': 'Unit 5653 Box 0998\nDPO AE 13155',
#   'Correo electrónico': 'duranchristopher@example.com',
#   'Fecha de nacimiento': datetime.date(1935, 6, 20)},
#  {'Nombre': 'Amanda',
#   'Apellido': 'Pena',
#   'Dirección': '3484 Patterson Springs\nKellyland, ID 55939',
#   'Correo electrónico': 'veronica27@example.net',
#   'Fecha de nacimiento': datetime.date(1986, 3, 16)},
#  {'Nombre': 'Steven',
#   'Apellido': 'Jones',
#   'Dirección': '24342 David Landing\nPort Matthewfurt, CT 85382',
#   'Correo electrónico': 'marshallcharles@example.org',
#   'Fecha de nacimiento': datetime.date(1928, 7, 9)},
#  {'Nombre': 'Brooke',
#   'Apellido': 'Williams',
#   'Dirección': '729 Scott Manor\nWest Ryanville, MI 15452',
#   'Correo electrónico': 'tina97@example.net',
#   'Fecha de nacimiento': datetime.date(1969, 9, 24)},
#  {'Nombre': 'Richard',
#   'Apellido': 'Boyer',
#   'Dirección': '08325 Crawford Underpass\nRamosmouth, UT 32582',
#   'Correo electrónico': 'apruitt@example.org',
#   'Fecha de nacimiento': datetime.date(2006, 6, 16)},
#  {'Nombre': 'Brian',
#   'Apellido': 'Young',
#   'Dirección': '62437 Matthew Junctions\nNew Kimberlystad, OR 62803',
#   'Correo electrónico': 'tannerbrown@example.com',
#   'Fecha de nacimiento': datetime.date(1963, 11, 13)},
#  {'Nombre': 'Steve',
#   'Apellido': 'Gomez',
#   'Dirección': '479 Samantha Rue Suite 437\nWesttown, WY 26160',
#   'Correo electrónico': 'karenjones@example.net',
#   'Fecha de nacimiento': datetime.date(1935, 9, 15)},
#  {'Nombre': 'Julie',
#   'Apellido': 'Carter',
#   'Dirección': '1593 Mary Road\nSouth Sandra, NM 16603',
#   'Correo electrónico': 'warnerrick@example.org',
#   'Fecha de nacimiento': datetime.date(2020, 11, 10)},
#  {'Nombre': 'Larry',
#   'Apellido': 'Perez',
#   'Dirección': '8912 Brian Junction Apt. 984\nLake Jasonview, KS 96846',
#   'Correo electrónico': 'morrisjane@example.com',
#   'Fecha de nacimiento': datetime.date(1930, 11, 4)},
#  {'Nombre': 'Ryan',
#   'Apellido': 'Fitzpatrick',
#   'Dirección': '803 Vincent Keys Suite 415\nMicheletown, IN 07896',
#   'Correo electrónico': 'mariahaustin@example.org',
#   'Fecha de nacimiento': datetime.date(1954, 1, 13)},
#  {'Nombre': 'Anthony',
#   'Apellido': 'Thomas',
#   'Dirección': '029 Bell Drive\nAmandamouth, ME 32669',
#   'Correo electrónico': 'garciascott@example.net',
#   'Fecha de nacimiento': datetime.date(1976, 6, 24)},
#  {'Nombre': 'Tracy',
#   'Apellido': 'Davis',
#   'Dirección': '081 Kevin Common\nJohnmouth, AZ 36976',
#   'Correo electrónico': 'kathryn22@example.com',
#   'Fecha de nacimiento': datetime.date(1972, 9, 28)},
#  {'Nombre': 'Steven',
#   'Apellido': 'Johnson',
#   'Dirección': '1907 Green Groves Apt. 295\nWilliamsside, DC 15394',
#   'Correo electrónico': 'regina36@example.com',
#   'Fecha de nacimiento': datetime.date(1950, 12, 1)},
#  {'Nombre': 'Tommy',
#   'Apellido': 'Clay',
#   'Dirección': '1890 Bradley Road\nChristensenberg, CT 67574',
#   'Correo electrónico': 'nicholas07@example.org',
#   'Fecha de nacimiento': datetime.date(2017, 2, 15)},
#  {'Nombre': 'Kevin',
#   'Apellido': 'Chapman',
#   'Dirección': '170 Calvin Burg Apt. 211\nNorth Matthew, KY 17591',
#   'Correo electrónico': 'wbentley@example.org',
#   'Fecha de nacimiento': datetime.date(1918, 11, 13)},
#  {'Nombre': 'Antonio',
#   'Apellido': 'Pierce',
#   'Dirección': '44081 Mary Stravenue Apt. 548\nJoycefort, WA 73864',
#   'Correo electrónico': 'ctaylor@example.org',
#   'Fecha de nacimiento': datetime.date(1910, 11, 22)},
#  {'Nombre': 'Erica',
#   'Apellido': 'Collins',
#   'Dirección': '070 Henry Mountains\nMeltonmouth, TN 98351',
#   'Correo electrónico': 'christophermartin@example.com',
#   'Fecha de nacimiento': datetime.date(1940, 6, 21)},
#  {'Nombre': 'Catherine',
#   'Apellido': 'Yu',
#   'Dirección': 'Unit 5115 Box 0561\nDPO AP 85532',
#   'Correo electrónico': 'markwest@example.com',
#   'Fecha de nacimiento': datetime.date(1919, 5, 20)},
#  {'Nombre': 'Robert',
#   'Apellido': 'Kramer',
#   'Dirección': '0135 David Vista\nShermanville, GU 59556',
#   'Correo electrónico': 'samuelcunningham@example.org',
#   'Fecha de nacimiento': datetime.date(1940, 9, 2)},
#  {'Nombre': 'Diana',
#   'Apellido': 'Elliott',
#   'Dirección': 'Unit 2757 Box 1584\nDPO AA 78032',
#   'Correo electrónico': 'scollins@example.org',
#   'Fecha de nacimiento': datetime.date(1921, 11, 12)},
#  {'Nombre': 'Michele',
#   'Apellido': 'Clark',
#   'Dirección': '666 Murray Manor Apt. 851\nNorth Karla, PA 33994',
#   'Correo electrónico': 'crystalmatthews@example.org',
#   'Fecha de nacimiento': datetime.date(1933, 5, 1)},
#  {'Nombre': 'Michele',
#   'Apellido': 'Waller',
#   'Dirección': '584 Evans Ports Apt. 577\nNorth Johnathan, HI 71797',
#   'Correo electrónico': 'andreavelasquez@example.org',
#   'Fecha de nacimiento': datetime.date(1986, 12, 5)},
#  {'Nombre': 'Caleb',
#   'Apellido': 'Gutierrez',
#   'Dirección': '90422 Montoya Ways\nScottborough, VT 40909',
#   'Correo electrónico': 'morganparker@example.com',
#   'Fecha de nacimiento': datetime.date(2019, 4, 22)},
#  {'Nombre': 'Tyler',
#   'Apellido': 'James',
#   'Dirección': '3183 Daniel Port\nNorth Leslietown, ND 43425',
#   'Correo electrónico': 'pmcdonald@example.net',
#   'Fecha de nacimiento': datetime.date(1950, 6, 18)},
#  {'Nombre': 'Ashley',
#   'Apellido': 'Stewart',
#   'Dirección': '69863 Crystal Route Suite 038\nMichelefurt, KS 30082',
#   'Correo electrónico': 'sophia85@example.net',
#   'Fecha de nacimiento': datetime.date(1980, 10, 7)},
#  {'Nombre': 'Michael',
#   'Apellido': 'Richard',
#   'Dirección': '6830 Juan Stream Suite 430\nSouth Deannaland, AZ 79336',
#   'Correo electrónico': 'phillipscatherine@example.org',
#   'Fecha de nacimiento': datetime.date(2008, 12, 14)},
#  {'Nombre': 'Bobby',
#   'Apellido': 'Richard',
#   'Dirección': '09872 Salazar Fields Suite 568\nSouth Richardmouth, FL 01125',
#   'Correo electrónico': 'piercejames@example.net',
#   'Fecha de nacimiento': datetime.date(2019, 12, 12)},
#  {'Nombre': 'Jonathan',
#   'Apellido': 'Collins',
#   'Dirección': '3829 Madison Orchard Apt. 861\nMcdanielhaven, MA 84541',
#   'Correo electrónico': 'kristi82@example.net',
#   'Fecha de nacimiento': datetime.date(1934, 9, 30)},
#  {'Nombre': 'Joseph',
#   'Apellido': 'Obrien',
#   'Dirección': '25207 Silva Lodge\nShelbychester, NE 80121',
#   'Correo electrónico': 'smithann@example.net',
#   'Fecha de nacimiento': datetime.date(1916, 3, 19)},
#  {'Nombre': 'Denise',
#   'Apellido': 'Ross',
#   'Dirección': '44388 Ho Spring\nPaynemouth, AS 44181',
#   'Correo electrónico': 'skim@example.org',
#   'Fecha de nacimiento': datetime.date(2000, 9, 28)},
#  {'Nombre': 'Karen',
#   'Apellido': 'Johnson',
#   'Dirección': '019 Jacob Crescent Suite 715\nEast Cynthialand, VA 12244',
#   'Correo electrónico': 'williamlee@example.org',
#   'Fecha de nacimiento': datetime.date(2001, 2, 1)},
#  {'Nombre': 'Jack',
#   'Apellido': 'Jensen',
#   'Dirección': '037 Davenport Ridges Apt. 888\nChristopherville, AZ 73469',
#   'Correo electrónico': 'smithamy@example.net',
#   'Fecha de nacimiento': datetime.date(1963, 1, 30)},
#  {'Nombre': 'Bruce',
#   'Apellido': 'Hansen',
#   'Dirección': 'USNS Crosby\nFPO AP 06971',
#   'Correo electrónico': 'nklein@example.com',
#   'Fecha de nacimiento': datetime.date(1944, 4, 1)},
#  {'Nombre': 'Jeremy',
#   'Apellido': 'Rogers',
#   'Dirección': '4106 James Cliff\nNew Erik, DE 85967',
#   'Correo electrónico': 'pchambers@example.com',
#   'Fecha de nacimiento': datetime.date(2009, 9, 18)},
#  {'Nombre': 'Christina',
#   'Apellido': 'York',
#   'Dirección': '1100 Graham Plains Suite 418\nMitchellberg, FL 55628',
#   'Correo electrónico': 'yuebony@example.com',
#   'Fecha de nacimiento': datetime.date(1984, 11, 9)},
#  {'Nombre': 'Michelle',
#   'Apellido': 'Barnett',
#   'Dirección': '663 West Lodge Apt. 817\nMillerberg, HI 93913',
#   'Correo electrónico': 'michael21@example.org',
#   'Fecha de nacimiento': datetime.date(1929, 4, 22)},
#  {'Nombre': 'Joshua',
#   'Apellido': 'Garcia',
#   'Dirección': '377 Stephanie Way Apt. 799\nRodriguezberg, ND 33860',
#   'Correo electrónico': 'hscott@example.net',
#   'Fecha de nacimiento': datetime.date(1992, 2, 15)},
#  {'Nombre': 'Megan',
#   'Apellido': 'Harvey',
#   'Dirección': '6438 Jennifer Canyon\nCaitlinton, AL 89775',
#   'Correo electrónico': 'hensleychristopher@example.net',
#   'Fecha de nacimiento': datetime.date(1934, 4, 13)},
#  {'Nombre': 'Andrew',
#   'Apellido': 'Gordon',
#   'Dirección': '8723 Richard Motorway Suite 374\nLake Donald, ND 60758',
#   'Correo electrónico': 'vickiehowell@example.com',
#   'Fecha de nacimiento': datetime.date(1911, 2, 22)},
#  {'Nombre': 'Colleen',
#   'Apellido': 'Oneal',
#   'Dirección': 'Unit 6401 Box 6699\nDPO AE 74325',
#   'Correo electrónico': 'melissa17@example.com',
#   'Fecha de nacimiento': datetime.date(1977, 6, 6)},
#  {'Nombre': 'Justin',
#   'Apellido': 'Macdonald',
#   'Dirección': '757 Cole Green\nHowellton, FM 91381',
#   'Correo electrónico': 'mlewis@example.net',
#   'Fecha de nacimiento': datetime.date(1908, 6, 14)},
#  {'Nombre': 'Grace',
#   'Apellido': 'Meyers',
#   'Dirección': '08178 William Estate Apt. 820\nHinesburgh, NY 58305',
#   'Correo electrónico': 'vbrooks@example.org',
#   'Fecha de nacimiento': datetime.date(1997, 10, 20)},
#  {'Nombre': 'Joseph',
#   'Apellido': 'Lee',
#   'Dirección': '639 Nguyen Valley\nPort Carly, KY 02933',
#   'Correo electrónico': 'alyssa51@example.org',
#   'Fecha de nacimiento': datetime.date(1926, 9, 21)},
#  {'Nombre': 'Jennifer',
#   'Apellido': 'Keller',
#   'Dirección': '085 Owens Point Apt. 205\nWest Lauratown, ME 38952',
#   'Correo electrónico': 'fscott@example.com',
#   'Fecha de nacimiento': datetime.date(1962, 3, 27)},
#  {'Nombre': 'Andrew',
#   'Apellido': 'Stokes',
#   'Dirección': '11077 Allen Loop Apt. 720\nPort Katelyn, WA 93067',
#   'Correo electrónico': 'jaimewilliams@example.org',
#   'Fecha de nacimiento': datetime.date(1983, 3, 19)},
#  {'Nombre': 'Brent',
#   'Apellido': 'Love',
#   'Dirección': '877 Troy Rapids Suite 599\nBryantfurt, NJ 09384',
#   'Correo electrónico': 'tammyjohnson@example.net',
#   'Fecha de nacimiento': datetime.date(1992, 10, 3)},
#  {'Nombre': 'Nicholas',
#   'Apellido': 'Roberts',
#   'Dirección': 'Unit 9265 Box 0261\nDPO AP 95456',
#   'Correo electrónico': 'kyle85@example.com',
#   'Fecha de nacimiento': datetime.date(2023, 1, 26)},
#  {'Nombre': 'Debra',
#   'Apellido': 'Nelson',
#   'Dirección': '48461 Maxwell Plain Suite 414\nLake Michael, VA 85134',
#   'Correo electrónico': 'iharvey@example.net',
#   'Fecha de nacimiento': datetime.date(1935, 12, 27)},
#  {'Nombre': 'Lisa',
#   'Apellido': 'Austin',
#   'Dirección': '5684 Paul Flat\nNorth Rebecca, CA 92453',
#   'Correo electrónico': 'oliviaescobar@example.org',
#   'Fecha de nacimiento': datetime.date(1978, 6, 10)},
#  {'Nombre': 'Nicholas',
#   'Apellido': 'Hernandez',
#   'Dirección': '16494 Coleman Dam Apt. 987\nPort Andreport, TX 15743',
#   'Correo electrónico': 'hray@example.com',
#   'Fecha de nacimiento': datetime.date(2007, 4, 8)},
#  {'Nombre': 'Anthony',
#   'Apellido': 'Hayes',
#   'Dirección': '37314 Whitney Prairie Suite 548\nTimothybury, PA 67345',
#   'Correo electrónico': 'sdavis@example.org',
#   'Fecha de nacimiento': datetime.date(1976, 11, 27)},
#  {'Nombre': 'Theresa',
#   'Apellido': 'Norman',
#   'Dirección': '14198 Nelson Glens Apt. 885\nPort Peter, MH 76550',
#   'Correo electrónico': 'karen31@example.com',
#   'Fecha de nacimiento': datetime.date(1924, 4, 10)},
#  {'Nombre': 'Sheri',
#   'Apellido': 'Gonzalez',
#   'Dirección': '7361 David Prairie Suite 265\nEast Amanda, AZ 75472',
#   'Correo electrónico': 'jennifer68@example.com',
#   'Fecha de nacimiento': datetime.date(1961, 12, 29)},
#  {'Nombre': 'Sally',
#   'Apellido': 'Davis',
#   'Dirección': '19373 Kelly Manors Suite 553\nNorth John, CO 46093',
#   'Correo electrónico': 'williamspaul@example.com',
#   'Fecha de nacimiento': datetime.date(1943, 6, 11)},
#  {'Nombre': 'Julie',
#   'Apellido': 'Spence',
#   'Dirección': '32525 Christopher Island Apt. 187\nPort Todd, MP 17897',
#   'Correo electrónico': 'vanessafoster@example.org',
#   'Fecha de nacimiento': datetime.date(1988, 2, 4)},
#  {'Nombre': 'Kevin',
#   'Apellido': 'Rodriguez',
#   'Dirección': '9470 Karen Falls\nNew Martinhaven, NV 07189',
#   'Correo electrónico': 'mary75@example.net',
#   'Fecha de nacimiento': datetime.date(2004, 9, 4)},
#  {'Nombre': 'Katherine',
#   'Apellido': 'Newman',
#   'Dirección': '904 Torres Green Suite 857\nWilliamschester, RI 86288',
#   'Correo electrónico': 'pscott@example.org',
#   'Fecha de nacimiento': datetime.date(1986, 9, 6)},
#  {'Nombre': 'Jeremy',
#   'Apellido': 'Trevino',
#   'Dirección': '058 Martin View\nJonesville, VT 87313',
#   'Correo electrónico': 'ostone@example.org',
#   'Fecha de nacimiento': datetime.date(1915, 5, 23)},
#  {'Nombre': 'Pamela',
#   'Apellido': 'Sanders',
#   'Dirección': '200 James Loaf\nSouth Susan, DC 74339',
#   'Correo electrónico': 'timothyvillarreal@example.org',
#   'Fecha de nacimiento': datetime.date(1953, 8, 30)},
#  {'Nombre': 'William',
#   'Apellido': 'Nolan',
#   'Dirección': '8430 Brown Tunnel Apt. 499\nRhodesburgh, UT 47099',
#   'Correo electrónico': 'joncastro@example.com',
#   'Fecha de nacimiento': datetime.date(1985, 3, 29)},
#  {'Nombre': 'Edward',
#   'Apellido': 'Thompson',
#   'Dirección': '340 Dennis Branch\nLoganview, VT 98699',
#   'Correo electrónico': 'velasquezvicki@example.org',
#   'Fecha de nacimiento': datetime.date(1911, 11, 11)},
#  {'Nombre': 'Cole',
#   'Apellido': 'Crawford',
#   'Dirección': '58326 Michael Cape Suite 064\nWeaverborough, VT 47520',
#   'Correo electrónico': 'udowns@example.com',
#   'Fecha de nacimiento': datetime.date(1917, 7, 25)},
#  {'Nombre': 'Kelly',
#   'Apellido': 'Moran',
#   'Dirección': '1500 Lewis Stravenue Apt. 516\nPierceview, KS 98210',
#   'Correo electrónico': 'maxwelllisa@example.org',
#   'Fecha de nacimiento': datetime.date(1973, 2, 27)},
#  {'Nombre': 'Amber',
#   'Apellido': 'Reynolds',
#   'Dirección': '9251 Nicole Glens\nNew Amy, TN 09560',
#   'Correo electrónico': 'brandoncox@example.com',
#   'Fecha de nacimiento': datetime.date(2004, 12, 19)},
#  {'Nombre': 'Thomas',
#   'Apellido': 'Jones',
#   'Dirección': '280 Black Summit Suite 215\nHarrellmouth, UT 49160',
#   'Correo electrónico': 'dduran@example.com',
#   'Fecha de nacimiento': datetime.date(2016, 2, 22)},
#  {'Nombre': 'Kathryn',
#   'Apellido': 'Malone',
#   'Dirección': '5565 Shannon Shore Suite 366\nNorth Sabrinaside, FL 37203',
#   'Correo electrónico': 'munozrussell@example.net',
#   'Fecha de nacimiento': datetime.date(1982, 5, 21)},
#  {'Nombre': 'Stacy',
#   'Apellido': 'Miller',
#   'Dirección': '5541 Williams Plaza Apt. 302\nNew Angel, NH 24819',
#   'Correo electrónico': 'wrightashley@example.com',
# ...
#   'Dirección': 'Unit 4204 Box 6900\nDPO AA 15593',
#   'Correo electrónico': 'lewistyler@example.net',
#   'Fecha de nacimiento': datetime.date(1978, 11, 17)},
#  {'Nombre': 'Brenda',
#   'Apellido': 'Mcgee',
#   'Dirección': '50849 Connie Forges Apt. 872\nPort Davidborough, CT 58739',
#   'Correo electrónico': 'fernandezcharles@example.org',
#   'Fecha de nacimiento': datetime.date(2020, 7, 31)},
#  {'Nombre': 'Bill',
#   'Apellido': 'Simon',
#   'Dirección': 'Unit 6548 Box 1753\nDPO AP 34333',
#   'Correo electrónico': 'gmorris@example.net',
#   'Fecha de nacimiento': datetime.date(1976, 12, 24)},
#  {'Nombre': 'Shelley',
#   'Apellido': 'Love',
#   'Dirección': '62504 Powell Terrace Apt. 635\nBaileymouth, VI 02331',
#   'Correo electrónico': 'matthew09@example.com',
#   'Fecha de nacimiento': datetime.date(1980, 8, 26)},
#  {'Nombre': 'Charles',
#   'Apellido': 'Thompson',
#   'Dirección': '571 Erickson Station Suite 870\nWest Jamiehaven, NJ 33548',
#   'Correo electrónico': 'markwilkerson@example.com',
#   'Fecha de nacimiento': datetime.date(1979, 5, 30)},
#  {'Nombre': 'Natalie',
#   'Apellido': 'Ramsey',
#   'Dirección': '08526 Roberta Village\nEast Darlenetown, MP 06187',
#   'Correo electrónico': 'baxterbrittany@example.net',
#   'Fecha de nacimiento': datetime.date(1909, 9, 21)},
#  {'Nombre': 'Joanne',
#   'Apellido': 'Thornton',
#   'Dirección': '47579 Barnes Forest\nRichardfort, WA 12660',
#   'Correo electrónico': 'mannmitchell@example.org',
#   'Fecha de nacimiento': datetime.date(1921, 1, 27)},
#  {'Nombre': 'Melissa',
#   'Apellido': 'Fitzgerald',
#   'Dirección': '4916 Johnson Ports Apt. 225\nWest Jamesside, TX 53659',
#   'Correo electrónico': 'whiteemily@example.net',
#   'Fecha de nacimiento': datetime.date(2006, 11, 1)},
#  {'Nombre': 'Matthew',
#   'Apellido': 'Sullivan',
#   'Dirección': '81842 David Gardens\nWeissfort, CA 03468',
#   'Correo electrónico': 'xscott@example.net',
#   'Fecha de nacimiento': datetime.date(1942, 1, 30)},
#  {'Nombre': 'Lauren',
#   'Apellido': 'Sweeney',
#   'Dirección': '8529 Ryan Road Apt. 808\nWest Hannahfort, NC 92849',
#   'Correo electrónico': 'pvega@example.org',
#   'Fecha de nacimiento': datetime.date(1960, 5, 3)},
#  {'Nombre': 'Clayton',
#   'Apellido': 'Stanley',
#   'Dirección': '91187 Campbell Drive Apt. 931\nTimothyburgh, NJ 58131',
#   'Correo electrónico': 'marvinwest@example.net',
#   'Fecha de nacimiento': datetime.date(1964, 6, 25)},
#  {'Nombre': 'Stephanie',
#   'Apellido': 'Johnson',
#   'Dirección': '77723 Alejandro Knoll\nNew Jamesview, OK 47506',
#   'Correo electrónico': 'mathew25@example.com',
#   'Fecha de nacimiento': datetime.date(1985, 3, 25)},
#  {'Nombre': 'Sarah',
#   'Apellido': 'Gomez',
#   'Dirección': '05332 Jones Manors\nStephenborough, OK 71308',
#   'Correo electrónico': 'rjohnson@example.org',
#   'Fecha de nacimiento': datetime.date(2009, 7, 14)},
#  {'Nombre': 'Heidi',
#   'Apellido': 'Jackson',
#   'Dirección': '440 Hayes Shoals\nNorth Matthew, IN 12283',
#   'Correo electrónico': 'richard56@example.com',
#   'Fecha de nacimiento': datetime.date(1985, 1, 22)},
#  {'Nombre': 'Emily',
#   'Apellido': 'Russell',
#   'Dirección': '1801 Martin Isle Suite 818\nPort Ashley, LA 36275',
#   'Correo electrónico': 'brandon96@example.org',
#   'Fecha de nacimiento': datetime.date(2022, 11, 7)},
#  {'Nombre': 'Ernest',
#   'Apellido': 'Ramirez',
#   'Dirección': '154 Katherine Tunnel Apt. 770\nStefanieland, ME 41449',
#   'Correo electrónico': 'leslie25@example.org',
#   'Fecha de nacimiento': datetime.date(1992, 10, 17)},
#  {'Nombre': 'Andrew',
#   'Apellido': 'Duncan',
#   'Dirección': '52227 Natalie Land Apt. 567\nNew Anna, MT 93824',
#   'Correo electrónico': 'hannah45@example.org',
#   'Fecha de nacimiento': datetime.date(2011, 6, 21)},
#  {'Nombre': 'Steven',
#   'Apellido': 'Ortiz',
#   'Dirección': '8816 Patricia Views\nDavisburgh, VI 21518',
#   'Correo electrónico': 'diana05@example.org',
#   'Fecha de nacimiento': datetime.date(1920, 6, 3)},
#  {'Nombre': 'Ryan',
#   'Apellido': 'Alvarez',
#   'Dirección': 'Unit 0602 Box 3629\nDPO AE 23251',
#   'Correo electrónico': 'nicolecross@example.org',
#   'Fecha de nacimiento': datetime.date(2000, 3, 8)},
#  {'Nombre': 'Breanna',
#   'Apellido': 'Gomez',
#   'Dirección': '429 Thomas Branch\nMorganville, MS 52970',
#   'Correo electrónico': 'wolfeamanda@example.org',
#   'Fecha de nacimiento': datetime.date(2009, 8, 27)},
#  {'Nombre': 'James',
#   'Apellido': 'Page',
#   'Dirección': '768 Velazquez Creek Apt. 449\nNew Christine, MO 22229',
#   'Correo electrónico': 'erin55@example.org',
#   'Fecha de nacimiento': datetime.date(1912, 10, 8)},
#  {'Nombre': 'Jesse',
#   'Apellido': 'Gallagher',
#   'Dirección': '68465 Anderson Views\nBakerburgh, LA 10154',
#   'Correo electrónico': 'phaley@example.com',
#   'Fecha de nacimiento': datetime.date(2018, 6, 24)},
#  {'Nombre': 'Kimberly',
#   'Apellido': 'Hall',
#   'Dirección': '41223 Rhonda Springs\nAndrewland, AL 37519',
#   'Correo electrónico': 'ericapope@example.com',
#   'Fecha de nacimiento': datetime.date(1996, 5, 10)},
#  {'Nombre': 'Taylor',
#   'Apellido': 'White',
#   'Dirección': 'Unit 9285 Box 5943\nDPO AE 62895',
#   'Correo electrónico': 'aandrews@example.net',
#   'Fecha de nacimiento': datetime.date(1967, 12, 24)},
#  {'Nombre': 'Kellie',
#   'Apellido': 'Sloan',
#   'Dirección': '937 Anderson Branch\nNorth Mason, NH 63551',
#   'Correo electrónico': 'bflowers@example.com',
#   'Fecha de nacimiento': datetime.date(1967, 7, 2)},
#  {'Nombre': 'John',
#   'Apellido': 'Walker',
#   'Dirección': '994 Kevin Mills Apt. 048\nTimothyberg, MO 54170',
#   'Correo electrónico': 'gilesnancy@example.net',
#   'Fecha de nacimiento': datetime.date(1970, 10, 4)},
#  {'Nombre': 'Barbara',
#   'Apellido': 'Perez',
#   'Dirección': '1442 Barbara Manor\nKathrynville, MA 61555',
#   'Correo electrónico': 'christophergilmore@example.net',
#   'Fecha de nacimiento': datetime.date(1908, 5, 15)},
#  {'Nombre': 'Melissa',
#   'Apellido': 'Anderson',
#   'Dirección': '94243 Jessica Park\nJenniferville, CO 90650',
#   'Correo electrónico': 'ppierce@example.com',
#   'Fecha de nacimiento': datetime.date(1981, 4, 28)},
#  {'Nombre': 'Allison',
#   'Apellido': 'Martin',
#   'Dirección': '711 William Pine\nAprilview, CA 83424',
#   'Correo electrónico': 'lindaadams@example.net',
#   'Fecha de nacimiento': datetime.date(2003, 10, 20)},
#  {'Nombre': 'James',
#   'Apellido': 'Brooks',
#   'Dirección': '85838 Jennifer Cliffs\nPort Dustinborough, TX 21320',
#   'Correo electrónico': 'jmaldonado@example.com',
#   'Fecha de nacimiento': datetime.date(1962, 11, 2)},
#  {'Nombre': 'Levi',
#   'Apellido': 'Landry',
#   'Dirección': 'Unit 7404 Box 5022\nDPO AP 22147',
#   'Correo electrónico': 'mraymond@example.net',
#   'Fecha de nacimiento': datetime.date(1988, 11, 4)},
#  {'Nombre': 'Gregory',
#   'Apellido': 'Singh',
#   'Dirección': '7866 Martin Course\nWeeksshire, AK 66830',
#   'Correo electrónico': 'lisalewis@example.org',
#   'Fecha de nacimiento': datetime.date(1924, 12, 12)},
#  {'Nombre': 'Carrie',
#   'Apellido': 'Phillips',
#   'Dirección': '010 Blackwell Place Apt. 966\nNorth Daisy, IN 08627',
#   'Correo electrónico': 'amber27@example.org',
#   'Fecha de nacimiento': datetime.date(2004, 6, 30)},
#  {'Nombre': 'Kenneth',
#   'Apellido': 'Combs',
#   'Dirección': '4381 Samuel Parkways\nLake Joseph, CT 74492',
#   'Correo electrónico': 'katherineosborn@example.net',
#   'Fecha de nacimiento': datetime.date(1952, 8, 2)},
#  {'Nombre': 'Glen',
#   'Apellido': 'Torres',
#   'Dirección': '5774 Snyder Crossroad Suite 662\nSouth Anthony, MO 13863',
#   'Correo electrónico': 'ross25@example.net',
#   'Fecha de nacimiento': datetime.date(1966, 9, 30)},
#  {'Nombre': 'Amy',
#   'Apellido': 'Hernandez',
#   'Dirección': '11558 Williams Green\nPort Ellenville, NE 99620',
#   'Correo electrónico': 'debra74@example.com',
#   'Fecha de nacimiento': datetime.date(1996, 9, 19)},
#  {'Nombre': 'Christopher',
#   'Apellido': 'Morrison',
#   'Dirección': '5506 Eric Radial Suite 975\nLake Robert, VA 83894',
#   'Correo electrónico': 'christophermendoza@example.com',
#   'Fecha de nacimiento': datetime.date(2008, 1, 7)},
#  {'Nombre': 'Lisa',
#   'Apellido': 'Clark',
#   'Dirección': '1299 John Pass\nPort Jeanne, VA 18348',
#   'Correo electrónico': 'cindyphillips@example.org',
#   'Fecha de nacimiento': datetime.date(1943, 8, 17)},
#  {'Nombre': 'Kimberly',
#   'Apellido': 'George',
#   'Dirección': '59181 Julia Ports\nDeanville, IA 63091',
#   'Correo electrónico': 'kyle54@example.com',
#   'Fecha de nacimiento': datetime.date(1930, 3, 13)},
#  {'Nombre': 'Lisa',
#   'Apellido': 'Watson',
#   'Dirección': '50002 Horn Roads\nLake Monica, TN 91798',
#   'Correo electrónico': 'dpowell@example.com',
#   'Fecha de nacimiento': datetime.date(2004, 8, 31)},
#  {'Nombre': 'Bethany',
#   'Apellido': 'Brown',
#   'Dirección': '3483 Julia Manor\nJohnsonborough, PR 00950',
#   'Correo electrónico': 'eric87@example.com',
#   'Fecha de nacimiento': datetime.date(1975, 5, 15)},
#  {'Nombre': 'Gregory',
#   'Apellido': 'Michael',
#   'Dirección': '47018 Ashley Ways Suite 095\nDennisberg, MP 83317',
#   'Correo electrónico': 'hernandezdavid@example.org',
#   'Fecha de nacimiento': datetime.date(1960, 9, 1)},
#  {'Nombre': 'Anthony',
#   'Apellido': 'Armstrong',
#   'Dirección': '467 Austin Parkways Apt. 370\nJosephmouth, AL 49228',
#   'Correo electrónico': 'donnaandrews@example.com',
#   'Fecha de nacimiento': datetime.date(1921, 11, 16)},
#  {'Nombre': 'Chloe',
#   'Apellido': 'Taylor',
#   'Dirección': '195 Martin Islands\nLake Allisonstad, PA 98386',
#   'Correo electrónico': 'mhensley@example.org',
#   'Fecha de nacimiento': datetime.date(2013, 9, 7)},
#  {'Nombre': 'Alicia',
#   'Apellido': 'Quinn',
#   'Dirección': '73087 Ann Crest\nPort Deborah, WA 93886',
#   'Correo electrónico': 'robert35@example.com',
#   'Fecha de nacimiento': datetime.date(2003, 9, 17)},
#  {'Nombre': 'Shannon',
#   'Apellido': 'Peterson',
#   'Dirección': '535 Hunter Cape\nPort Nathan, PA 04271',
#   'Correo electrónico': 'turneralexander@example.com',
#   'Fecha de nacimiento': datetime.date(1969, 4, 22)},
#  {'Nombre': 'Nicole',
#   'Apellido': 'Harrison',
#   'Dirección': '20761 Justin Spring\nPort Tim, NH 92082',
#   'Correo electrónico': 'delacruzmarissa@example.net',
#   'Fecha de nacimiento': datetime.date(1910, 5, 9)},
#  {'Nombre': 'Sheri',
#   'Apellido': 'Brooks',
#   'Dirección': '1035 Brown Ramp\nPort Gary, MS 50480',
#   'Correo electrónico': 'patrick34@example.org',
#   'Fecha de nacimiento': datetime.date(1926, 6, 19)},
#  {'Nombre': 'Eric',
#   'Apellido': 'Garcia',
#   'Dirección': '09100 Christopher Street Suite 925\nWilliamstad, GU 16283',
#   'Correo electrónico': 'jleon@example.net',
#   'Fecha de nacimiento': datetime.date(1924, 8, 31)},
#  {'Nombre': 'Mark',
#   'Apellido': 'Alvarado',
#   'Dirección': '217 Turner Station Suite 420\nWest Brittany, OK 29334',
#   'Correo electrónico': 'joshuagreene@example.net',
#   'Fecha de nacimiento': datetime.date(1918, 7, 8)},
#  {'Nombre': 'Jennifer',
#   'Apellido': 'Martinez',
#   'Dirección': '9967 Mitchell Creek\nBrittneychester, MA 97615',
#   'Correo electrónico': 'kathyallen@example.org',
#   'Fecha de nacimiento': datetime.date(1989, 12, 7)},
#  {'Nombre': 'Jacob',
#   'Apellido': 'Hancock',
#   'Dirección': '7354 Anderson Trafficway\nGarciaburgh, IL 64428',
#   'Correo electrónico': 'conradsusan@example.org',
#   'Fecha de nacimiento': datetime.date(1949, 9, 28)},
#  {'Nombre': 'Mark',
#   'Apellido': 'Williams',
#   'Dirección': '2839 Jacob Lodge\nAshleychester, MA 55339',
#   'Correo electrónico': 'gvargas@example.com',
#   'Fecha de nacimiento': datetime.date(1935, 10, 1)},
#  {'Nombre': 'Meghan',
#   'Apellido': 'Harris',
#   'Dirección': '4217 Mullins Turnpike Apt. 088\nDaniellemouth, DC 10739',
#   'Correo electrónico': 'jenniferjohnson@example.net',
#   'Fecha de nacimiento': datetime.date(2018, 3, 6)},
#  {'Nombre': 'Cynthia',
#   'Apellido': 'Gonzales',
#   'Dirección': '60364 Johnson Passage Apt. 764\nMcdanielfort, OH 22132',
#   'Correo electrónico': 'lovemelissa@example.org',
#   'Fecha de nacimiento': datetime.date(2007, 6, 21)},
#  {'Nombre': 'Diana',
#   'Apellido': 'Pace',
#   'Dirección': '7219 Gonzalez Harbor\nPort Stacyport, CO 01643',
#   'Correo electrónico': 'amygregory@example.net',
#   'Fecha de nacimiento': datetime.date(2007, 6, 27)},
#  {'Nombre': 'Joe',
#   'Apellido': 'Martin',
#   'Dirección': '88924 Barrett Squares\nSouth Clintontown, OR 75553',
#   'Correo electrónico': 'fmiller@example.net',
#   'Fecha de nacimiento': datetime.date(1937, 12, 4)},
#  {'Nombre': 'Jacob',
#   'Apellido': 'Russell',
#   'Dirección': '592 Martin Walk Apt. 895\nMakaylabury, IA 95851',
#   'Correo electrónico': 'rgarcia@example.com',
#   'Fecha de nacimiento': datetime.date(1916, 5, 22)},
#  {'Nombre': 'Jenna',
#   'Apellido': 'George',
#   'Dirección': '53703 Patrick Points\nWest Ethan, MI 53388',
#   'Correo electrónico': 'patrickramos@example.com',
#   'Fecha de nacimiento': datetime.date(1936, 3, 21)},
#  {'Nombre': 'Dana',
#   'Apellido': 'Robinson',
#   'Dirección': '036 Allen Heights Suite 274\nLake Juan, AL 48336',
#   'Correo electrónico': 'yolanda66@example.net',
#   'Fecha de nacimiento': datetime.date(1938, 7, 6)},
#  {'Nombre': 'Xavier',
#   'Apellido': 'Bishop',
#   'Dirección': '1838 Tate Extensions Suite 251\nMurphyview, KY 90885',
#   'Correo electrónico': 'alexander51@example.net',
#   'Fecha de nacimiento': datetime.date(2024, 4, 21)},
#  {'Nombre': 'Carrie',
#   'Apellido': 'Ross',
#   'Dirección': '95079 Austin Points\nKyleville, IL 47013',
#   'Correo electrónico': 'courtney36@example.org',
#   'Fecha de nacimiento': datetime.date(1986, 2, 14)},
#  {'Nombre': 'Patrick',
#   'Apellido': 'Moore',
#   'Dirección': '57393 Butler Flats Apt. 530\nEast Joshua, ND 97044',
#   'Correo electrónico': 'cmay@example.org',
#   'Fecha de nacimiento': datetime.date(1944, 2, 8)},
#  {'Nombre': 'April',
#   'Apellido': 'Chandler',
#   'Dirección': '08707 John Mews\nHamiltonfurt, ND 87111',
#   'Correo electrónico': 'rachel13@example.net',
#   'Fecha de nacimiento': datetime.date(1929, 9, 25)},
#  {'Nombre': 'Daniel',
#   'Apellido': 'Grant',
#   'Dirección': '411 Steven Pass\nThomasville, WY 47145',
#   'Correo electrónico': 'smithmaria@example.net',
#   'Fecha de nacimiento': datetime.date(2002, 4, 13)},
#  {'Nombre': 'Matthew',
#   'Apellido': 'Martinez',
#   'Dirección': '37344 Perry Manor\nCourtneyburgh, GU 72644',
#   'Correo electrónico': 'mooneyjessica@example.com',
#   'Fecha de nacimiento': datetime.date(1969, 12, 26)},
#  {'Nombre': 'Michael',
#   'Apellido': 'Charles',
#   'Dirección': '15568 Johnson Villages\nNorth Donna, UT 56019',
#   'Correo electrónico': 'oharris@example.net',
#   'Fecha de nacimiento': datetime.date(1942, 2, 9)},
#  {'Nombre': 'Jacob',
#   'Apellido': 'Scott',
#   'Dirección': '3995 Keith Squares\nAmandashire, RI 63416',
#   'Correo electrónico': 'sfrye@example.net',
#   'Fecha de nacimiento': datetime.date(1931, 10, 22)},
#  {'Nombre': 'Jesse',
#   'Apellido': 'Fuller',
#   'Dirección': '60743 Lee Well Suite 497\nWhitechester, HI 49673',
#   'Correo electrónico': 'itapia@example.net',
#   'Fecha de nacimiento': datetime.date(1933, 6, 18)},
#  {'Nombre': 'Jason',
#   'Apellido': 'Vasquez',
#   'Dirección': '17240 Alexander Squares\nSouth Charlesview, PR 54950',
#   'Correo electrónico': 'christian83@example.net',
#   'Fecha de nacimiento': datetime.date(1952, 4, 29)},
#  {'Nombre': 'Steven',
#   'Apellido': 'Logan',
#   'Dirección': '79330 Thomas Knoll Suite 948\nTraviston, MA 71614',
#   'Correo electrónico': 'jimoconnor@example.com',
#   'Fecha de nacimiento': datetime.date(2015, 11, 7)},
#  {'Nombre': 'Marcia',
#   'Apellido': 'Wells',
#   'Dirección': '38579 Nicholas Motorway Apt. 735\nLake Janicebury, OR 06388',
#   'Correo electrónico': 'hermanedward@example.org',
#   'Fecha de nacimiento': datetime.date(1999, 2, 8)},
#  {'Nombre': 'John',
#   'Apellido': 'Reilly',
#   'Dirección': '4828 Coleman Lake Apt. 727\nCindyton, NY 58441',
#   'Correo electrónico': 'yvonne27@example.com',
#   'Fecha de nacimiento': datetime.date(2001, 11, 5)},
#  {'Nombre': 'Kenneth',
#   'Apellido': 'Roberts',
#   'Dirección': '6532 Wood Junction\nNew Cindymouth, WY 53551',
#   'Correo electrónico': 'karen42@example.net',
#   'Fecha de nacimiento': datetime.date(1946, 7, 23)},
#  {'Nombre': 'Ronnie',
#   'Apellido': 'Schaefer',
#   'Dirección': '7231 Miller Road\nPort William, AK 78565',
#   'Correo electrónico': 'iparker@example.com',
#   'Fecha de nacimiento': datetime.date(2008, 12, 20)}]

# %%
data = pd.DataFrame(lista)

# %%
rango=range(1,len(data)+1)
data.index=rango

# %%
data
# Out:
#        Nombre  Apellido                                          Dirección  \
# 1      Rachel   Coleman       5757 Thompson Overpass\nClarkmouth, FL 20893
# 2        John     Burns      404 Renee Wall Apt. 092\nNew Joshua, PA 85625
# 3     Douglas    Ortega             819 Ward Plains\nEast Monica, KY 81125
# 4       Diana   Bradley         0962 Amanda Crest\nSouth Abigail, VA 50910
# 5        Chad    Atkins  7960 Katherine Ferry Apt. 849\nLake Lisa, WY 1...
# ...       ...       ...                                                ...
# 996    Steven     Logan  79330 Thomas Knoll Suite 948\nTraviston, MA 71614
# 997    Marcia     Wells  38579 Nicholas Motorway Apt. 735\nLake Janiceb...
# 998      John    Reilly     4828 Coleman Lake Apt. 727\nCindyton, NY 58441
# 999   Kenneth   Roberts       6532 Wood Junction\nNew Cindymouth, WY 53551
# 1000   Ronnie  Schaefer           7231 Miller Road\nPort William, AK 78565
#
#              Correo electrónico Fecha de nacimiento
# 1       manningtina@example.com          1931-03-06
# 2          brownamy@example.org          1967-04-24
# 3           ywilson@example.org          1980-06-05
# 4     hatfieldethan@example.org          2013-08-10
# 5         stephen15@example.com          2006-10-08
# ...                         ...                 ...
# 996      jimoconnor@example.com          2015-11-07
# 997    hermanedward@example.org          1999-02-08
# 998        yvonne27@example.com          2001-11-05
# 999         karen42@example.net          1946-07-23
# 1000        iparker@example.com          2008-12-20
#
# [1000 rows x 5 columns]

# %%
cedula=1102792826
def generar_cedula(d):
    global cedula
    cedula+=1
    return cedula

# %%
data['Cédula']=data['Nombre'].apply(generar_cedula)

# %%
data = data[['Cédula'] + [col for col in data.columns if col != 'Cédula']]

# %%
data
# Out:
#           Cédula   Nombre  Apellido  \
# 1     1102792827   Rachel   Coleman
# 2     1102792828     John     Burns
# 3     1102792829  Douglas    Ortega
# 4     1102792830    Diana   Bradley
# 5     1102792831     Chad    Atkins
# ...          ...      ...       ...
# 996   1102793822   Steven     Logan
# 997   1102793823   Marcia     Wells
# 998   1102793824     John    Reilly
# 999   1102793825  Kenneth   Roberts
# 1000  1102793826   Ronnie  Schaefer
#
#                                               Dirección  \
# 1          5757 Thompson Overpass\nClarkmouth, FL 20893
# 2         404 Renee Wall Apt. 092\nNew Joshua, PA 85625
# 3                819 Ward Plains\nEast Monica, KY 81125
# 4            0962 Amanda Crest\nSouth Abigail, VA 50910
# 5     7960 Katherine Ferry Apt. 849\nLake Lisa, WY 1...
# ...                                                 ...
# 996   79330 Thomas Knoll Suite 948\nTraviston, MA 71614
# 997   38579 Nicholas Motorway Apt. 735\nLake Janiceb...
# 998      4828 Coleman Lake Apt. 727\nCindyton, NY 58441
# 999        6532 Wood Junction\nNew Cindymouth, WY 53551
# 1000           7231 Miller Road\nPort William, AK 78565
#
#              Correo electrónico Fecha de nacimiento
# 1       manningtina@example.com          1931-03-06
# 2          brownamy@example.org          1967-04-24
# 3           ywilson@example.org          1980-06-05
# 4     hatfieldethan@example.org          2013-08-10
# 5         stephen15@example.com          2006-10-08
# ...                         ...                 ...
# 996      jimoconnor@example.com          2015-11-07
# 997    hermanedward@example.org          1999-02-08
# 998        yvonne27@example.com          2001-11-05
# 999         karen42@example.net          1946-07-23
# 1000        iparker@example.com          2008-12-20
#
# [1000 rows x 6 columns]

# %%
data.to_csv("data.csv", index=False)

# %%
data_parte1=data.drop(columns=["Correo electrónico","Fecha de nacimiento"],inplace=False)
data_parte2=data.drop(columns=["Nombre","Apellido","Dirección"],inplace=False)

# %%
data_parte1.to_csv("data_parte1.csv", index=False)
data_parte2.to_csv("data_parte2.csv", index=False)

# %%
data_parte1
# Out:
#           Cédula   Nombre  Apellido  \
# 1     1102792827   Rachel   Coleman
# 2     1102792828     John     Burns
# 3     1102792829  Douglas    Ortega
# 4     1102792830    Diana   Bradley
# 5     1102792831     Chad    Atkins
# ...          ...      ...       ...
# 996   1102793822   Steven     Logan
# 997   1102793823   Marcia     Wells
# 998   1102793824     John    Reilly
# 999   1102793825  Kenneth   Roberts
# 1000  1102793826   Ronnie  Schaefer
#
#                                               Dirección
# 1          5757 Thompson Overpass\nClarkmouth, FL 20893
# 2         404 Renee Wall Apt. 092\nNew Joshua, PA 85625
# 3                819 Ward Plains\nEast Monica, KY 81125
# 4            0962 Amanda Crest\nSouth Abigail, VA 50910
# 5     7960 Katherine Ferry Apt. 849\nLake Lisa, WY 1...
# ...                                                 ...
# 996   79330 Thomas Knoll Suite 948\nTraviston, MA 71614
# 997   38579 Nicholas Motorway Apt. 735\nLake Janiceb...
# 998      4828 Coleman Lake Apt. 727\nCindyton, NY 58441
# 999        6532 Wood Junction\nNew Cindymouth, WY 53551
# 1000           7231 Miller Road\nPort William, AK 78565
#
# [1000 rows x 4 columns]

# %%
data_parte2
# Out:
#           Cédula         Correo electrónico Fecha de nacimiento
# 1     1102792827    manningtina@example.com          1931-03-06
# 2     1102792828       brownamy@example.org          1967-04-24
# 3     1102792829        ywilson@example.org          1980-06-05
# 4     1102792830  hatfieldethan@example.org          2013-08-10
# 5     1102792831      stephen15@example.com          2006-10-08
# ...          ...                        ...                 ...
# 996   1102793822     jimoconnor@example.com          2015-11-07
# 997   1102793823   hermanedward@example.org          1999-02-08
# 998   1102793824       yvonne27@example.com          2001-11-05
# 999   1102793825        karen42@example.net          1946-07-23
# 1000  1102793826        iparker@example.com          2008-12-20
#
# [1000 rows x 3 columns]

# %%
data_parte1_recuperado = pd.read_csv("data_parte1.csv")

# %%
data_parte1_recuperado
data_parte1_recuperado.index=rango
data_parte1_recuperado
# Out:
#           Cédula   Nombre  Apellido  \
# 1     1102792827   Rachel   Coleman
# 2     1102792828     John     Burns
# 3     1102792829  Douglas    Ortega
# 4     1102792830    Diana   Bradley
# 5     1102792831     Chad    Atkins
# ...          ...      ...       ...
# 996   1102793822   Steven     Logan
# 997   1102793823   Marcia     Wells
# 998   1102793824     John    Reilly
# 999   1102793825  Kenneth   Roberts
# 1000  1102793826   Ronnie  Schaefer
#
#                                               Dirección
# 1          5757 Thompson Overpass\nClarkmouth, FL 20893
# 2         404 Renee Wall Apt. 092\nNew Joshua, PA 85625
# 3                819 Ward Plains\nEast Monica, KY 81125
# 4            0962 Amanda Crest\nSouth Abigail, VA 50910
# 5     7960 Katherine Ferry Apt. 849\nLake Lisa, WY 1...
# ...                                                 ...
# 996   79330 Thomas Knoll Suite 948\nTraviston, MA 71614
# 997   38579 Nicholas Motorway Apt. 735\nLake Janiceb...
# 998      4828 Coleman Lake Apt. 727\nCindyton, NY 58441
# 999        6532 Wood Junction\nNew Cindymouth, WY 53551
# 1000           7231 Miller Road\nPort William, AK 78565
#
# [1000 rows x 4 columns]

# %%
dataframe_unido=pd.merge(data_parte1_recuperado,data_parte2, on='Cédula')
dataframe_unido.index=rango
dataframe_unido
# Out:
#           Cédula   Nombre  Apellido  \
# 1     1102792827   Rachel   Coleman
# 2     1102792828     John     Burns
# 3     1102792829  Douglas    Ortega
# 4     1102792830    Diana   Bradley
# 5     1102792831     Chad    Atkins
# ...          ...      ...       ...
# 996   1102793822   Steven     Logan
# 997   1102793823   Marcia     Wells
# 998   1102793824     John    Reilly
# 999   1102793825  Kenneth   Roberts
# 1000  1102793826   Ronnie  Schaefer
#
#                                               Dirección  \
# 1          5757 Thompson Overpass\nClarkmouth, FL 20893
# 2         404 Renee Wall Apt. 092\nNew Joshua, PA 85625
# 3                819 Ward Plains\nEast Monica, KY 81125
# 4            0962 Amanda Crest\nSouth Abigail, VA 50910
# 5     7960 Katherine Ferry Apt. 849\nLake Lisa, WY 1...
# ...                                                 ...
# 996   79330 Thomas Knoll Suite 948\nTraviston, MA 71614
# 997   38579 Nicholas Motorway Apt. 735\nLake Janiceb...
# 998      4828 Coleman Lake Apt. 727\nCindyton, NY 58441
# 999        6532 Wood Junction\nNew Cindymouth, WY 53551
# 1000           7231 Miller Road\nPort William, AK 78565
#
#              Correo electrónico Fecha de nacimiento
# 1       manningtina@example.com          1931-03-06
# 2          brownamy@example.org          1967-04-24
# 3           ywilson@example.org          1980-06-05
# 4     hatfieldethan@example.org          2013-08-10
# 5         stephen15@example.com          2006-10-08
# ...                         ...                 ...
# 996      jimoconnor@example.com          2015-11-07
# 997    hermanedward@example.org          1999-02-08
# 998        yvonne27@example.com          2001-11-05
# 999         karen42@example.net          1946-07-23
# 1000        iparker@example.com          2008-12-20
#
# [1000 rows x 6 columns]
